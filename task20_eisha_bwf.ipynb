# %% [markdown]
# **Regression in keras an example**

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense

# Load the Boston Housing dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
dataframe = pd.read_csv(url, delim_whitespace=True, names=names)

# Split the dataset into input features and target variable
X = dataframe.drop('MEDV', axis=1).values
y = dataframe['MEDV'].values

# Define the model architecture
model = Sequential()
model.add(Dense(13, input_dim=13, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, y, epochs=150, batch_size=10)

# Predict on new data
new_data = np.array([[0.1, 18.0, 2.31, 0.0, 0.54, 6.58, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98]])
prediction = model.predict(new_data)
print(prediction)
# Out:
# Epoch 1/150
# 51/51 [==============================] - 1s 2ms/step - loss: 1007.4824
# Epoch 2/150
# 51/51 [==============================] - 0s 2ms/step - loss: 197.1668
# Epoch 3/150
# 51/51 [==============================] - 0s 2ms/step - loss: 104.8991
# Epoch 4/150
# 51/51 [==============================] - 0s 2ms/step - loss: 91.9172
# Epoch 5/150
# 51/51 [==============================] - 0s 2ms/step - loss: 90.8093
# Epoch 6/150
# 51/51 [==============================] - 0s 2ms/step - loss: 81.3771
# Epoch 7/150
# 51/51 [==============================] - 0s 2ms/step - loss: 74.4576
# Epoch 8/150
# 51/51 [==============================] - 0s 2ms/step - loss: 68.9675
# Epoch 9/150
# 51/51 [==============================] - 0s 2ms/step - loss: 66.2861
# Epoch 10/150
# 51/51 [==============================] - 0s 2ms/step - loss: 66.0199
# Epoch 11/150
# 51/51 [==============================] - 0s 2ms/step - loss: 61.7303
# Epoch 12/150
# ...
